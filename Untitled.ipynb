# %%
import pygmsh as pg
import paraview
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-0d0b35761e96> in <module>
#       1 import pygmsh as pg
# ----> 2 import paraview
#
# ModuleNotFoundError: No module named 'paraview'

# %%
import pyvista as pv
from pyvista import examples

# %%
# Get a sample file
filename = examples.planefile
filename
# Out:
# '/home/nijso/anaconda3/lib/python3.7/site-packages/pyvista/examples/airplane.ply'

# %%
mesh = pv.read(filename)
cpos = mesh.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FD122429950>

# %%
cgnsfile=pv.read('/home/nijso/bs.msh')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pyvista/utilities/fileio.py in read(filename, attrs, file_format)
#     208         try:
# --> 209             reader = get_reader(filename)
#     210             return standard_reader_routine(reader, filename)
#
# ~/anaconda3/lib/python3.7/site-packages/pyvista/utilities/fileio.py in get_reader(filename)
#      83     ext = get_ext(filename)
# ---> 84     return READERS[ext]() # Get and instantiate the reader
#      85
#
# KeyError: '.msh'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-556ca64ef3cd> in <module>
# ----> 1 cgnsfile=pv.read('/home/nijso/bs.msh')
#
# ...
